# %%
import pandas as pd

df = pd.read_csv("Olist.csv")

# cette transformation est juste pour avoir int8 au lieu de int64
int_col = ["payment_sequential","payment_installments","review_score","product_photos_qty"]
object_col = ["order_item_id","customer_zip_code_prefix","seller_zip_code_prefix"]

for col in int_col:

    df[col] = pd.to_numeric(df[col], errors='coerce',downcast='integer')

# for col in object_col:
    df[col] = df[col].astype(str)
    
df.head()
# Out:
#                            order_id order_status order_purchase_timestamp  \
# 0  e481f51cbdc54678b7cc49136f2d6af7    delivered               2017-10-02
# 1  e481f51cbdc54678b7cc49136f2d6af7    delivered               2017-10-02
# 2  e481f51cbdc54678b7cc49136f2d6af7    delivered               2017-10-02
# 3  53cdb2fc8bc7dce0b6741e2150273451    delivered               2018-07-24
# 4  47770eb9100c2d0c44946d9cf07ec65d    delivered               2018-08-08
#
#   order_delivered_customer_date order_estimated_delivery_date  \
# 0                    2017-10-10                    2017-10-18
# 1                    2017-10-10                    2017-10-18
# 2                    2017-10-10                    2017-10-18
# 3                    2018-08-07                    2018-08-13
# 4                    2018-08-17                    2018-09-04
#
#    payment_sequential payment_type  payment_installments  payment_value  \
# ...

# %% [markdown]
# ## Group by & Aggrégation

# %%
# group by customer unique id

mode_col = ['payment_sequential','payment_type','payment_installments','product_id',
            'seller_id','customer_zip_code_prefix','customer_city','customer_state','seller_zip_code_prefix','seller_city']
mean_col = ['payment_value','price','freight_value','review_score','seller_state','product_category_name']
last_col = ['order_purchase_timestamp','order_delivered_customer_date','order_estimated_delivery_date','review_answer_timestamp']
count_col = ['order_id']
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113232 entries, 0 to 113231
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       113232 non-null  object
#  1   order_status                   113232 non-null  object
#  2   order_purchase_timestamp       113232 non-null  object
#  3   order_delivered_customer_date  113232 non-null  object
#  4   order_estimated_delivery_date  113232 non-null  object
#  5   payment_sequential             113232 non-null  int8
#  6   payment_type                   113232 non-null  object
#  7   payment_installments           113232 non-null  int8
#  8   payment_value                  113232 non-null  float64
#  9   order_item_id                  113232 non-null  float64
#  10  product_id                     113232 non-null  object
#  11  seller_id                      113232 non-null  object
# ...
